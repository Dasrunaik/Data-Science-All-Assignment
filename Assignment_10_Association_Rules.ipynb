# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasrunaik/AssignMents-ExcelR/blob/main/Assignment_10_Association_Rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df=pd.read_excel('/content/Online retail.xlsx')
df
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
df.shape
# Out:
# (7500, 1)

# %%
df.describe()
# Out:
#        shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# count                                                7500
# unique                                               5175
# top                                               cookies
# freq                                                  223

# %%
df.dtypes
# Out:
# shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil    0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil']

# %%
df.columns = df.columns.str.strip()

# %%
df.head()
# Out:
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Convert each transaction into a list of items**

# %%
transactions = df.iloc[:, 0].dropna().apply(lambda x: [item.strip() for item in str(x).split(',')])
transactions
# Out:
# 0                              [burgers, meatballs, eggs]
# 1                                               [chutney]
# 2                                       [turkey, avocado]
# 3       [mineral water, milk, energy bar, whole wheat ...
# 4                                        [low fat yogurt]
#                               ...
# 7495                    [butter, light mayo, fresh bread]
# 7496    [burgers, frozen vegetables, eggs, french frie...
# 7497                                            [chicken]
# 7498                                [escalope, green tea]
# 7499    [eggs, frozen smoothie, yogurt cake, low fat y...
# Name: shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil, Length: 7500, dtype: object

# %%
te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)
basket = pd.DataFrame(te_data, columns=te.columns_)
basket
# Out:
#       almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0       False              False      False    False        False  False
# 1       False              False      False    False        False  False
# 2       False              False      False     True        False  False
# 3       False              False      False    False        False  False
# 4       False              False      False    False        False  False
# ...       ...                ...        ...      ...          ...    ...
# 7495    False              False      False    False        False  False
# 7496    False              False      False    False        False  False
# 7497    False              False      False    False        False  False
# 7498    False              False      False    False        False  False
# 7499    False              False      False    False        False  False
#
#       barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# ...

# %% [markdown]
# **Association Rule Mining with Apriori**

# %%
# Apply the Apriori algorithm
frequent_items = apriori(basket, min_support=0.02, use_colnames=True)
frequent_items
# Out:
#       support                           itemsets
# 0    0.020267                          (almonds)
# 1    0.033200                          (avocado)
# 2    0.033733                         (brownies)
# 3    0.087200                          (burgers)
# 4    0.030133                           (butter)
# ..        ...                                ...
# 99   0.020133  (mineral water, whole wheat rice)
# 100  0.022933             (olive oil, spaghetti)
# 101  0.025200              (pancakes, spaghetti)
# 102  0.021200                (shrimp, spaghetti)
# 103  0.020933              (spaghetti, tomatoes)
#
# [104 rows x 2 columns]

# %%
#Generate association rules
rules = association_rules(frequent_items, metric="lift", min_threshold=1.0)
rules
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0        (burgers)           (eggs)            0.087200            0.179733
# 1           (eggs)        (burgers)            0.179733            0.087200
# 2        (burgers)   (french fries)            0.087200            0.170933
# 3   (french fries)        (burgers)            0.170933            0.087200
# 4        (burgers)  (mineral water)            0.087200            0.238267
# ..             ...              ...                 ...                 ...
# 91     (spaghetti)       (pancakes)            0.174133            0.095067
# 92        (shrimp)      (spaghetti)            0.071333            0.174133
# 93     (spaghetti)         (shrimp)            0.174133            0.071333
# 94     (spaghetti)       (tomatoes)            0.174133            0.068400
# 95      (tomatoes)      (spaghetti)            0.068400            0.174133
#
# ...

# %%
#Set thresholds to extract meaningful rules
rules_filtered = rules[(rules['confidence'] >= 0.3) & (rules['lift'] >= 3)]
rules_filtered
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
rules_sorted = rules_filtered.sort_values(by='lift', ascending=False)
rules_sorted
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %% [markdown]
# **Analysis and Interpretation**

# %%
top_rules = rules_sorted[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
top_rules.head(10)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %% [markdown]
# 1.What is lift and why is it important in Association rules?
#
# Lift is a metric that measures how much more likely two items are to be purchased together than if they were purchased independently.

# %% [markdown]
# 2.What is support and Confidence. How do you calculate them?
#
#        Support measures how frequently an itemset in the dataset
#
#        Support(A)= Number of Transactions containing A  / Total number of Transactions
#
#
#        Confidence:
#
#
#          Confidence measures how often item B is purchased when item A is purchased.
#
#
#
#             Confidence(A→B)=Support(A)  /  Support(A∪B)
# ​

# %% [markdown]
# 3.	What are some limitations or challenges of Association rules mining?
#
#
# 1)Generates a large number of rules, many of which may be trivial or irrelevant.
#
# 2)Requires manual filtering or setting high thresholds for support/lift/confidence.
